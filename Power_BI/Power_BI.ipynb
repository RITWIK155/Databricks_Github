# %%
DAX: The formula language in Power BI used to create calculations and custom logic in your model.
EX:
    create column(right click on column name) 
    COALESCE: Function replaces nulls by returning the first value that is not empty.
    column = COALESCE(Table[column], 0) #This column will replace by 0

Power Query: Tool in Power Bi. Used to clean, shape and prepare your data before loading it into the model. (It does initial step that involve cleaning & preparing the data before moving/importing to Power BI)
*Analytics nag: PQ enables you to discover, connect, combine, transform data from various sources.
*Power Query Purpose: 1. Cleaning (Datatypes changes, Replace NULL/Fill the data if it blank, Remove Duplicates)
                     2. Transforming/Shaping (Identify Headers, Renaming, Remove Columns/Rows, Add Columns, Append, Merge Inner Join/left Join)
                     3. Data Profile (Data Anomalies, Column Distribution, Column Quality, Column profile)
EX: Home->Transform Data(Transform Data)->Power Query
    File->Close & Apply (Save in power Query)

DAX vs Power Query:
DAX have more Mathematical and Analytical formulas than clean up the data.

Excel->Pwer Query/DAX-> sent to Power BI for Visuals

Applied Steps:
Shows each transformation you made in Power Query Step by Step

#Power Bi vs pagenated report :
= Power Bi not full page will shown while Report Builder is full report upto end page.     
= Pagenated report is for printing
Ability to print all the data in a table 
Limited Data Sources (RDL )Much data not needed
No data model (RDL)
Modify your data by filtering, grouping, and sorting data, or by adding formulas or expressions (PBIX)
Rdl Vs pbix
                # GPT #Power Bi vs pagenated report :
+----------------+----------------------------------------+---------------------------------------+
| Feature        | RDL (Paginated Reports)                | PBIX (Power BI Desktop)               |
+----------------+----------------------------------------+---------------------------------------+
| Primary Goal   | Perfect for printing or generating     | Designed for interactive,             |
|                | fixed-layout documents (e.g.,          | exploratory data analysis and         |
|                | invoices).                             | visualization.                        |
+----------------+----------------------------------------+---------------------------------------+
| Data Model     | Generally does not use a complex       | Built on the powerful VertiPaq engine |
|                | internal model; relies on direct       | with a robust relational data model.  |
|                | queries.                               |                                       |
+----------------+----------------------------------------+---------------------------------------+
| Layout         | Fixed-layout; the report expands to    | Responsive/Dynamic layout; widgets    |
|                | fit the amount of data across pages.   | adjust based on container size.       |
+----------------+----------------------------------------+---------------------------------------+
| Interactivity  | Very limited interactivity for the     | Highly interactive (cross-filtering,  |
|                | end user.                              | tooltips, drill-throughs).            |
+----------------+----------------------------------------+---------------------------------------+
| Data Sources   | Often optimized for operational,       | Optimized for connected data          |
|                | high-volume transactional data         | modeling from multiple sources via    |
|                | sources.                               | Power Query.                          |
+----------------+----------------------------------------+---------------------------------------+

✅ # Report builder connect data source and bring data to data source?
https://www.youtube.com/watch?v=0ZLAdriWzT4&list=PLjNd3r1KLjQs-JsZ-PSb6gBKWu7F9GtPZ&index=3
Table(insert table & Drag drop by default 3 column 2 rows)
✅ # what data should be populated/Report Defination in Report builder?
https://www.youtube.com/watch?v=0ZLAdriWzT4&list=PLjNd3r1KLjQs-JsZ-PSb6gBKWu7F9GtPZ&index=3
= click table row of Report builder(choose databse-table-column)->Add Title(List of Products Reports)->Run: Till 9 page report will went.
= select that column ->Bold/colore(RED)
✅ # Power BI add one new column(new price):
fields-> (take particular table 3 dot: new measure: new price = sum(DimProduct[ListPrice] - 2))
✅ # power BI - one visualization already there. You want another visualization/subfield on the same page?
= minimize and drag 1st visual to left side (so you get some space) & Drag Table(from visual) Drag any table value & & count/sum from value 
✅ # make power Bi visual vialable?
= Drag Format Painter to that visual-> automatic it will went to good visual
✅ #Report builder add one new column(new price):
= Table ->right click(Insert column->Right)-> ✅ give header name(new price)->Beneath(right click->Expression) click Fields(that 2 table)click ListPrice(=Fields!ListPrice.Value-2 Automatically come)-> ok ->Run
✅ #Report builder add one new Matrix(new price):
->inseert->matrix. Same you can drag right click table value expression sum(procudtkey)->expression->count(productkey)->Run (Give group by result)

# %%
                # Create Chart in Paginated report
insert ->chart inser chat & drag (you can select pie chart also)
Table Wizer : helps one after another in table

How to change query in Pagenated report?
= right click on dataset->Edit query->ok->run
            #### Row Groups & Column Groups
= Use to Group By in your column dataset to display result.
= Row group->add group->child group->groupby: salesteritorycountry. salesteritory->add group->after
#Select Multiple rows in Pagenated report?
= shift+ctrl
            ###EXPRESSION###
#How to find function expression ex: Sum/Avg?
= right click->common function->Aggregate
#How to make 2 digit dashamik?
= right click->textbox property->Number:number:2->ok->run
#How to put color if order_quantity is < 100 red and >100 green?
= click that cell->Property:Background:Expression->common function:Aggregate: =if (SUM("select order_quamtuty from field")>100, "Green","Red")->ok
            ###Parameters###
When u launch report you need to provide parameter. User can coose some filter  
Parameter->rightclick Add Parameter->Dataset->add dataset->Datatype: Boolean, Text, Integer: Text. Available Values: How this values going to appear  
            ###Sorting value###
Click on any colmn/column header->right click:Tablix Properties->sorting-> z to a
            ###Enable sorting on report/ User can sort from UI Report###
rightclick columnvalue textbox->textbox property->Interactive Sorting->Enable Sorting->sort by: EnglishProductName->ok->run
            ###Enable Header on Everypage###
click entire table->column groups: dropdown: Advanced Mode->row group: static->property:repeat:True

# %%
1) What is Power BI
= 
Comprehensive Business Intelligence & Data Visualization Platform

To Transform data from various Sources & Data Modeling as well

Create Interactive, Actionable Visually Immersive Insights

Securely share your Reports / Dashboards with Business Users
2) WHY Power BI
[Data Sources]                                                               [Users]
(Sales, Production, etc.)                                                        (Consumers)
          |                                                                           ^
          |                                                                           |
          v                creating DAX/Calculated measure                            |
  +-----------------+      +-----------------+      +-----------------+      +-----------------+
  |   Power Query   | ---> |   Power Pivot   | ---> |   Power View    | ---> |    Power BI     |
  | (ETL/Transform) |      |     (Model)     |      |    (Report)     |      |     Service     |
  +-----------------+      +-----------------+      +-----------------+      +-----------------+
          |                                                                           |
          +---------------------------------------------------------------------------+
                                     Power BI Desktop
Report View: Where you will be able to create report.
Table View & Data: List of table imported will appear.
Model View: You can create relationship between tables & you can create calculated column and Measures. It will appear in Data->Model sec.
DAX:
TMDL:
#Power BI Desktop right side:
Data: Whatever Table/Data you imported it will appear here.
Visualization: What visual need to be created in canvas.
Filters: you can filter on this page or all pages. Because you can create multiple pages here. Filters on all pages: Filter will be applicable on multiple pages.

For Trend analysis use Trend Chart.
= select sale date & item quantity from Data It will come as table & now click trend chart from visual.
EX: Sum of Item Quantity by year & Month
click Arraw to change only month.

Cluster Column 
= Sum of item Quantity by Location. X: Location, Y: Sum of item Quantity

Card
= Single value. Ex: sum of item Quantity

Donut Chart
= Sum of item Quantity by Order type name. X: Location,

Filters
= What location it sold. We will use slicer. As end user can do filter using slicer.
Ex: select slicer. select Catagory, -> Format Visual ->Style: Dropdown

# %%
                            # Power Query
Remove Rows: 
    open excel->Transform Data->Remove Rows->Remove Top Rows: 1
Make First Row as Header:
    Home->Use First Row as Header   
    If you Already load the Data:
        Home->Transform Data->  Home->Use First Row as Header 
How To fill blank/NULL data any value of particular column Power Query?
= Select aprticular column in Power Query. 
  Select column(Order_Name)->Replace Value (NULL: Not Available/anything)
Remove Duplicates:
    = Shift -> Remove duplicates
