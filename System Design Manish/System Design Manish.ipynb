# %%
System design round is Vaugue and no answer is perfect. So if you make different different solution that is also becoming correct. It is just that how you have approached.

Q1) Is SDE and DE system design same?
= No , SDE: login, cdn, caching, tokenization, maps, ride sharing data. So this will not asked in DE. 
Q2) Manish where did you learn System designand any book course yt?
= Manish followed Books: 'System Design Interview' - Alex XU. (2) It ius like Bible for everyone: Designing data Intensive Application. (3) If any one want for streaming data 'Kafka the Definative Guide'- Real time Data and stream processing at Scala. 
= Youtube playlist: Arpit Bhayani. some time gourav Sen

Q3) Only Madelian Architecture is not a system design.
= It is a part not system design. 

Q. Design an e‑commerce platform?
Step1:
→ Let’s understand what e‑commerce means here ? Rule no 1 → Never assume always clarify. → They don’t need solution they need approach and Cnn't guessing.
Q2. Are you asking me to build transactional or analytical system ?
Q3. Who will be the end consumer of the do.
Q4. What is the scale of data and what the anticipated scale in upcoming 6 months?
Q4. What is the scale of data and what is the anticipated scale in upcoming 6 month or a year
