# %%
                                    #Tree
Its a linked list. A linked list is a tree that does not fork. 

                                    # Binary Tree
Binary tree have two arrow like this.
                                ④
                              ↙   ↘
in the code look like this, dictionary
{
    "value": 4,
    "left": None,
    "right": None
}                              
            Value point in two other nodes : 1.56
                          ④
                        ↙   ↘
                        ③    ㉓
Basically:             
{
    "value": 4,
    "left": {
        "value": 3,
        "left": None,
        "right": None 
    },
    "right": {
        "value": 23,
        "left": None,
        "right" : None
    }
} 
                                # Full Tree
                            Image:                ④
                                                ↙  ↘
                                               ③    ㉓
                                              ↙ ↘
                                             ⑫   ⑦
Full Tree: In Full tree every Node either points to zero nodes or two nodes. 
                                # Purfect Tree
                            Image: ④
                                  ↙ ↘
                                  ③ ㉓
Perfect Tree: In Perfect Tree any level in the tree that has any nodes is completely filled all the way accross.
                            2nd Image:  ④
                                       ↙ ↘
                                      ③   ㉓
                                     ↙ ↘ ↙ ↘
                                     ⑫ ⑦ ⑭ ㉗
If we remove it is no longer perfect it is full. 3rd Image : 2.46 
                            # FUll Perfect, Complete
Complete Tree is filling left to right
                            image: 3.37
                                #Parent & Child Node
4 is parent of this 2 child/sibling node(3,23). So have only 1 parent
          ④ Parent
         / \
       ③   ㉓
      ↑     ↑
    Child Child
Child node can also be parent node
           ④
         /   \
       ③      ㉓
      / \    /  \
    ⑫    ⑰   ⑭  ㉗
                        #Leaf Node
Nodes that does not have any children is called leaf.
Ex: Above ex 12, 17, 14 27 are leaf                        
                            # When a Tree is not a Tree
When a tree has more than one parent , It is not a tree.

# %%
                                        # Binary Search Tree
Binary Search Tree is not a Binary tree.
