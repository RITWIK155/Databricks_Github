# %% [markdown]
# Interview EY Aiswaraya Pani:
# SQl:
# 1. Find 2nd heighest salary
# 2. Different b/w rank,dense rank,row number
# 3. They will give 2 tables having some ids and ask you output of left,right,full,inner,self join
#
# PYSPARK:
# 1. Different read format and diffn write format.
# 2. How you will apply filter condition.
# 3. How to use with column renamed.
# 4. How you will read csv file & how you will write in a parquet format.
# 5. Basic transformation like Drop Malformed,Drop Duplicate function & what is the uses.
# 6. How you will check if there is missing null , if null how you convert it in particular value.
#
# DATABRICKS:
# 1. Delta Live tables.
# 2. What is Delta,External,Managed Tables.
# 3. 3 name space, Unity catalog
#
# DATAWAREHOUSE:
# 1. Basic datawarehouse quistion like OLAP vs OLTP , Snowflake & Star Schema, Fact & Dimension table.
#
# BASIC CLOUD QUISTION:
# 1. Different cloud model :Private,Public,Hybrid cloud.
#
# DATA GOVERNANCE RELATED QUISTION:
# 1. What is ARM,
# 2. What is Azure cloud.
# 3. Difference between AWS and AZURE (VVI)
#
# SCENERIO BASED QUISTION:
# 1. Give quistion to write in pyspark as well convert in sql.
#
# ONE CODING QUISTION:
# 1. Mainly from Array, list, Tuple, Dictionary, Set. Basic DSA is sufficient
#
# ————————————————————————————————————————————————————————
# Linkdin: Sachin Chandrashekhar: Learn These Concepts to be proficient in Python.
#
# 𝐁𝐚𝐬𝐢𝐜𝐬 𝐨𝐟 𝐏𝐲𝐭𝐡𝐨𝐧:
#
#  -Syntax & Style
#  -Data Types
#  -Variables & Operators
#  -Control Flow: if/else, Loops, try/except
#  -Functions & Modules
#
# 𝐎𝐛𝐣𝐞𝐜𝐭-𝐎𝐫𝐢𝐞𝐧𝐭𝐞𝐝 𝐏𝐲𝐭𝐡𝐨𝐧:
#
#  -Classes & Objects
#  -Inheritance
#  -Polymorphism
#  -Encapsulation
#
# 𝐊𝐞𝐲 𝐋𝐢𝐛𝐫𝐚𝐫𝐢𝐞𝐬:
#
#  -Pandas: Data Manipulation
#  -Requests: pull and post data through API
#  -SQLAlchemy: Connect to databases
#
# 𝐏𝐚𝐧𝐝𝐚𝐬 𝐢𝐧 𝐃𝐞𝐩𝐭𝐡:
#
#  -DataFrames: Creation & Access
#  -Filtering & Selection
#  -Data Cleaning: Missing Values, Duplicates
#  -Merging & Grouping
#
# 𝐃𝐚𝐭𝐚 𝐒𝐭𝐫𝐮𝐜𝐭𝐮𝐫𝐞𝐬:
#
#  -Lists
#  -Tuples
#  -Dictionaries
#  -Sets
#
# 𝐅𝐢𝐥𝐞 𝐇𝐚𝐧𝐝𝐥𝐢𝐧𝐠:
#
#  -Text Files
#  -CSV Files
#  -JSON Files
# —————
# Linkdin : Abhishek Agrawal
#
# Databricks :
# You cannot clear a Databricks interview without knowing these 10 differences.
# 1)RDD VS DataFrame vs. Dataset
# 2)Cache vs. Persist
# 3)Repartition vs. Coalesce
# 4)Databricks Workflows vs. Delta Live Tables
# 5)Unity Catalog vs. Delta Lake
# 6)AQE vs. Catalyst Optimizer
# 7)Broadcast vs. Sort Merge Join
# 8)Parquet vs. CSV
# 9)Managed vs. Unmanaged Tables
# 10)Transformations vs. Actions

# %%
Interview EY Aiswaraya Pani:
SQl: 
1. Find 2nd heighest salary
2. Different b/w rank,dense rank,row number
3. They will give 2 tables having some ids and ask you output of left,right,full,inner,self join

PYSPARK:
1. Different read format and diffn write format.
2. How you will apply filter condition.
3. How to use with column renamed.
4. How you will read csv file & how you will write in a parquet format.
5. Basic transformation like Drop Malformed,Drop Duplicate function & what is the uses. 
6. How you will check if there is missing null , if null how you convert it in particular value.

DATABRICKS:
1. Delta Live tables. 
2. What is Delta,External,Managed Tables.
3. 3 name space, Unity catalog

DATAWAREHOUSE:
1. Basic datawarehouse quistion like OLAP vs OLTP , Snowflake & Star Schema, Fact & Dimension table.

BASIC CLOUD QUISTION:
1. Different cloud model :Private,Public,Hybrid cloud.

DATA GOVERNANCE RELATED QUISTION:
1. What is ARM, 
2. What is Azure cloud.
3. Difference between AWS and AZURE (VVI)

SCENERIO BASED QUISTION:
1. Give quistion to write in pyspark as well convert in sql.

ONE CODING QUISTION:
1. Mainly from Array, list, Tuple, Dictionary, Set. Basic DSA is sufficient

————————————————————————————————————————————————————————
Linkdin: Sachin Chandrashekhar: Learn These Concepts to be proficient in Python.

𝐁𝐚𝐬𝐢𝐜𝐬 𝐨𝐟 𝐏𝐲𝐭𝐡𝐨𝐧:

 -Syntax & Style
 -Data Types
 -Variables & Operators
 -Control Flow: if/else, Loops, try/except
 -Functions & Modules

𝐎𝐛𝐣𝐞𝐜𝐭-𝐎𝐫𝐢𝐞𝐧𝐭𝐞𝐝 𝐏𝐲𝐭𝐡𝐨𝐧:

 -Classes & Objects
 -Inheritance
 -Polymorphism
 -Encapsulation

𝐊𝐞𝐲 𝐋𝐢𝐛𝐫𝐚𝐫𝐢𝐞𝐬:

 -Pandas: Data Manipulation
 -Requests: pull and post data through API
 -SQLAlchemy: Connect to databases 

𝐏𝐚𝐧𝐝𝐚𝐬 𝐢𝐧 𝐃𝐞𝐩𝐭𝐡:

 -DataFrames: Creation & Access
 -Filtering & Selection
 -Data Cleaning: Missing Values, Duplicates
 -Merging & Grouping

𝐃𝐚𝐭𝐚 𝐒𝐭𝐫𝐮𝐜𝐭𝐮𝐫𝐞𝐬:

 -Lists
 -Tuples
 -Dictionaries
 -Sets

𝐅𝐢𝐥𝐞 𝐇𝐚𝐧𝐝𝐥𝐢𝐧𝐠:

 -Text Files
 -CSV Files
 -JSON Files
—————
Linkdin : Abhishek Agrawal

Databricks : 
You cannot clear a Databricks interview without knowing these 10 differences.
1)RDD VS DataFrame vs. Dataset
2)Cache vs. Persist
3)Repartition vs. Coalesce
4)Databricks Workflows vs. Delta Live Tables
5)Unity Catalog vs. Delta Lake
6)AQE vs. Catalyst Optimizer
7)Broadcast vs. Sort Merge Join
8)Parquet vs. CSV
9)Managed vs. Unmanaged Tables
10)Transformations vs. Actions
