# %%
# where
import pandas as pd
df = pd.DataFrame({"name": ["A","B","C"], "age": [25,40,20]})
df.where(df['age'] > 30)

# %%
# explode
import pandas as pd
data = {
    'id': [1, 2],
    'name': ['Alice', 'Bob'],
    'tags': [['SQL', 'Python'], ['Spark']]
}
df = pd.DataFrame(data)
display(df)
# df.explode('tags')
df.melt(id_vars='tags')
