# %%
Hadoop is widely adopted, powerfull and simple tool for computing Big Data. 
What is Big Data?
=> See previous note book

How Big is Big Data?
= Do you call 100GB data is Big data or Terabytes/Petabytes data is Big Data? It depends on 3 Vs. 
Volume: Megabytes, Gigabytes, Terabytes, Petabytes
Velocity/Speed: Miliseconds, seconds, Minutes, Hour, Daily, Weekly, Batch
Variety: Text, Sensor data, Legacy docs, Image, Audio, Video

Big Data Toolsets: Cassendra, MongoDB, GREENPLUM DATABASE, Hadoop, Hive, Spark, Avro, Apache Hbase, PostgreSQL. 
Apache Hadoop: is one of the toolsets that enables us to deal with Big data. But Hadoop is not only one (see avove). Google was the first company to solve the Big Data problem. they disclosed the solution in 2003 by publishing a paper in Google_file_system. This article provided Distributed file system to read and write the large data efficiently. 2nd part released 2004 using MapReduce. This present a framework to process a file stored in google file system. After so many iteration Hadoop comes in 2011. Initially Hadoop 1.0 has 2 core components:
            - A distributed file system (HDFS)
            - A distributed programming framework (called as: Map Reduce)
Open source community release with one more component Hadoop 2.0 in 2012:
            - A distributed file system (HDFS)
            - A distributed programming framework (called as: Map Reduce)
            - YARN
No core component Hadoop 3.0 alpha2 in 2012.

Hadoop Ecosystem: (Hive, Spark, Kafka most adopted component only need to learn these)
- Hive
- Pig
- HBase
- Spark
- Sqoop
- Flume
- Kafka
- Oozie

HDFS:
H: Hadoop
D: Distributed
F: File
S: System
Operating System ---- File System (HDFS) ---- Folder ----+
                                                   |
                                                   +---- Directory ---- file
                                                   |                     file
                                                   |
                                                   +---- Directory
                                                   |
                                                   +---- Directory ---- file

Do you know what is  File system?
= If you have computer you know File system. File system allows you to create directory and files. Then you can perform some operations on them like copy from one to another location/rename/move them/Delete them. 
HDFS is also a file system. From HDFS you can do Crreate some directories and store your data in files. 
Q)You can ask if it is file system then why Hadoop is so popular.   
= It is good thing google published in the paper. Why people build file system when we have so many of them. I mean every Operating System comes with default file systems. But Hadoop is not a ordinary file system. The creators of Hadoop designed with some special capabilities and features that make it unique.
