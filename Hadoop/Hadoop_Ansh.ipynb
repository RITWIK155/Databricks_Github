# %%
What is BIG DATA?
= Data is Big in size. Ex: In yt you liked some videos , share commenting, buyed some course all things generates data. So like this from many user generates BIG DATA. 40M record

Problems 
I have acomputer storing 1 GB of data now data size reched to 100 GB. THen you say you can say you increase the size of computer. BUt big data means volume is increasing.

# 3 Vs of Big Data
1. VOLUME
2. VELOCITY/SPEED: today you have 1 gb after one month 10 gb data and after 1 week 10 gb to 100 gb or after one dat 1000gb.Then it reaches 1TB. Then people realise data size/Volume is not a problem, With speed as well it is growing so rapidly. You cannot upscale a storage so so quick. 
3. VARIETY: previously we getting data as Tabularand structured format. But now getting variety of data video/pdf/images/text Semistructured as well as Unstructured data as well.
            Unstructured: Images, Videos
            Semistructured: Means It has some structure but it can change. Ex: JSON
