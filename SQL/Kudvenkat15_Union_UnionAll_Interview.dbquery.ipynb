-- %%
UNION ALL: Used to get all the records including duplicates.
UNION: Used to get all the records without duplicates and sorted order in ssms.

Used Tables: tblIndiaCustomers, tblUKCustomers

-- ###tblIndiaCustomers
Id | Name | Email
1  | Raj  | R@R.com
2  | Sam  | S@S.com
-- ###tblUKCustomers
Id | Name | Email
1  | Ben  | B@B.com
2  | Sam  | S@S.com
-- ###Query Results of UNION ALL
Id | Name | Email
1  | Raj  | R@R.com
2  | Sam  | S@S.com
1  | Ben  | B@B.com
2  | Sam  | S@S.com
-- ###Table 4: Query Results of UNION
Id | Name | Email
1  | Ben  | B@B.com
1  | Raj  | R@R.com
2  | Sam  | S@S.com

select * from tblIndiaCustomers
UNION ALL
select * from tblUKCustomers

select * from tblIndiaCustomers
UNION 
select * from tblUKCustomers

-- ### 1) Interview: Differences between UNION and UNION ALL (Common Interview Question)
= UNION removes duplicate rows, where as UNION ALL does not. When use UNION, to remove the duplicate rows, sql server has to to do a distinct sort, which is time consuming. For this reason, UNION ALL is much faster than UNION. 

Note: If you want to see the cost of DISTINCT SORT, you can turn on the estimated query execution plan using CTRL + L.

Note: For UNION and UNION ALL to work, the Number, Data types, and the order of the columns in the select statements should be same

-- ### 2) Difference between JOIN and UNION
= JOIN combines data horizontally (side-by-side), adding new columns.
= UNION combines data vertically (stacking), adding new rows.
