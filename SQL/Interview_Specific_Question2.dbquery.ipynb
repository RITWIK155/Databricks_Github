-- %%
-- from Manish: https://datapathsala.com/interview/sql
--Q8) How to retrieve last 10/5 records from a table? -- table: tblemployee
select * from tblemployee order by ID DESC 
LIMIT 5

-- Q20) Fetch First and Last record from a table?  -- table: tblemployee
(select * from tblemployee order by ID ASC LIMIT 1)
UNION ALL
(select * from tblemployee order by ID DESC LIMIT 1)
