-- %%
Table: tblProducts, tblProductSales

-- A non-corelated subquery (Select Distinct ProductId from tblProductSales)can be executed independently of the outer query. 
Select Id, Name, Description 
from tblProducts where Id not in (Select Distinct ProductId from tblProductSales)
